# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

# %%
with open("matrix.dat") as f:
    data = np.loadtxt(f, dtype ="float64", delimiter = ",")

# %%
xlist = range(data.shape[0])
ylist = range(data.shape[1])
X, Y = np.meshgrid(xlist, ylist)
plt.figure()
cp = plt.contourf(X, Y, data, cmap)
plt.colorbar(cp)
plt.title('RMDS of the Structures Recovered by MDS')
plt.ylabel('No. Points Missing')
plt.xlabel("Noise Standard Deviation")
fig1 = plt.gcf()
